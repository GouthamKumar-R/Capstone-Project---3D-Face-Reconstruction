# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Thinkpad-E470\\Downloads\\titanic\\Capstone'

# %%
fname=[]
count=0
for root, dirs, files in os.walk("C:\\Users\\Thinkpad-E470\\Downloads\\titanic\\Capstone"):
    for file in files:
        if file.endswith(".mat"):
             print(os.path.join(root, file))
             fname.append(os.path.join(root, file))
             count=count+1
# Out:
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-010_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-011_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-012_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-013_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-015_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-016_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-017_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-020_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-023_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-024_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-027_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-034_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-035_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\002__002-001_0.mat
# ...

# %%
import random
xf=np.empty([53215,])
yf=np.empty([53215,])
zf=np.empty([53215,])
xcount=0
ycount=0
zcount=0
for i in range(0,count):
    data = scipy.io.loadmat(fname[i])
    X = data['shape'][0]
    Y = data['shape'][1]
    Z = data['shape'][2]
    xrand=random.randint(1, 10)
    yrand=random.randint(1, 10)
    zrand=random.randint(1, 10)
    xcount=xcount+xrand
    ycount=ycount+yrand
    zcount=zcount+zrand
    xf=xf+(X*xrand)
    yf=yf+(Y*yrand)
    zf=zf+(Z*zrand)

# %%
xf1=xf/xcount
yf1=yf/ycount
zf1=zf/zcount

# %%
xcount
# Out:
# 129

# %%
ycount
# Out:
# 157

# %%
zcount
# Out:
# 134

# %%
xf1
# Out:
# array([-58270.07102008, -58245.93850351, -58228.392545  , ...,
#         59752.25214566,  59532.89808488,  59297.21913334])

# %%
spmat=np.array([xf1,yf1,zf1])

# %%
scipy.io.savemat('new.mat', {'shape': spmat})

# %%
data = scipy.io.loadmat('new.mat')
X = data['shape'][0]
Y = data['shape'][1]
Z = data['shape'][2]

# %%
# %matplotlib notebook

# %%
#new
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.view_init(90, -90)
#for i in range(4,53215):
surf = ax.plot_trisurf(X, Y, Z, linewidth=0, antialiased=False)
#ax.scatter3D(X, Y, Z, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Advanced Model

# %%
fname=[]
count=0
for root, dirs, files in os.walk("C:\\Users\\Thinkpad-E470\\Downloads\\titanic\\Capstone"):
    for file in files:
        if file.endswith(".mat"):
             print(os.path.join(root, file))
             fname.append(os.path.join(root, file))
             count=count+1
# Out:
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-010_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-011_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-012_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-013_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-015_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-016_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-017_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-020_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-023_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-024_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-027_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-034_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-035_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\002__002-001_0.mat
# ...

# %%
import random
xf=np.empty([53215,])
yf=np.empty([53215,])
zf=np.empty([53215,])
xparam=np.empty([53215,count])
yparam=np.empty([53215,count])
zparam=np.empty([53215,count])
for i in range(0,count):
    data = scipy.io.loadmat(fname[i])
    X = data['shape'][0]
    Y = data['shape'][1]
    Z = data['shape'][2]
    xrand=np.random.randint(10, size=(53215))
    yrand=np.random.randint(10, size=(53215))
    zrand=np.random.randint(10, size=(53215))
    xparam[:,i]=xrand
    yparam[:,i]=yrand
    zparam[:,i]=zrand
    xf=xf+(X*xrand)
    yf=yf+(Y*yrand)
    zf=zf+(Z*zrand)

# %%
xparam
# Out:
# array([[6., 9., 4., ..., 5., 6., 9.],
#        [4., 0., 7., ..., 2., 3., 4.],
#        [3., 6., 0., ..., 1., 9., 6.],
#        ...,
#        [5., 4., 6., ..., 0., 3., 3.],
#        [0., 5., 4., ..., 4., 9., 3.],
#        [4., 2., 5., ..., 6., 3., 6.]])

# %%
xf.shape
# Out:
# (53215,)

# %%
np.sum(xparam, axis = 1).shape
# Out:
# (53215,)

# %%
xf[1]
# Out:
# -5303478.679026222

# %%
np.sum(xparam, axis = 1)[1]
# Out:
# 91.0

# %%
xf1=xf/np.sum(xparam, axis = 1)
yf1=yf/np.sum(yparam, axis = 1)
zf1=zf/np.sum(zparam, axis = 1)

# %%
xf1
# Out:
# array([-57844.25740884, -58279.9854838 , -57400.57334369, ...,
#         61438.87934473,  61738.55737521,  59768.17140065])

# %%
spmat=np.array([xf1,yf1,zf1])

# %%
scipy.io.savemat('new2.mat', {'shape': spmat})

# %%
data = scipy.io.loadmat('new2.mat')
X = data['shape'][0]
Y = data['shape'][1]
Z = data['shape'][2]

# %%
# %matplotlib notebook

# %%
#new2
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.view_init(90, -90)
#for i in range(4,53215):
surf = ax.plot_trisurf(X, Y, Z, linewidth=0, antialiased=False)
#ax.scatter3D(X, Y, Z, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#new2
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.view_init(90, -90)
#for i in range(4,53215):
surf = ax.plot_trisurf(X, Y, Z, linewidth=0, antialiased=False)
#ax.scatter3D(X, Y, Z, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Alternate Random inputs

# %%
fname=[]
count=0
for root, dirs, files in os.walk("C:\\Users\\Thinkpad-E470\\Downloads\\titanic\\Capstone"):
    for file in files:
        if file.endswith(".mat"):
             print(os.path.join(root, file))
             fname.append(os.path.join(root, file))
             count=count+1
# Out:
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-010_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-011_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-012_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-013_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-015_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-016_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-017_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-020_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-023_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-024_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-027_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-034_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\001__001-035_0.mat
# C:\Users\Thinkpad-E470\Downloads\titanic\Capstone\002__002-001_0.mat
# ...

# %%
import random
xf=np.empty([53215,])
yf=np.empty([53215,])
zf=np.empty([53215,])
xparam=np.empty([53215,count])
yparam=np.empty([53215,count])
zparam=np.empty([53215,count])
for i in range(0,count):
    data = scipy.io.loadmat(fname[i])
    X = data['shape'][0]
    Y = data['shape'][1]
    Z = data['shape'][2]
    xrand=np.random.randint(100, size=(53215))
    yrand=np.random.randint(100, size=(53215))
    zrand=np.random.randint(100, size=(53215))
    xparam[:,i]=xrand
    yparam[:,i]=yrand
    zparam[:,i]=zrand
    xf=xf+(X*xrand)
    yf=yf+(Y*yrand)
    zf=zf+(Z*zrand)

# %%
xparam
# Out:
# array([[65., 79., 95., ..., 91.,  6., 81.],
#        [64., 39., 56., ..., 42., 89., 68.],
#        [55., 36., 35., ..., 30., 21., 65.],
#        ...,
#        [ 8.,  3.,  7., ..., 95.,  3.,  7.],
#        [16., 59., 35., ..., 12., 43., 42.],
#        [34., 13., 72., ..., 58., 55., 27.]])

# %%
xf.shape
# Out:
# (53215,)

# %%
np.sum(xparam, axis = 1).shape
# Out:
# (53215,)

# %%
xf[1]
# Out:
# -75130766.40992431

# %%
np.sum(xparam, axis = 1)[1]
# Out:
# 1295.0

# %%
xf1=xf/np.sum(xparam, axis = 1)
yf1=yf/np.sum(yparam, axis = 1)
zf1=zf/np.sum(zparam, axis = 1)

# %%
xf1
# Out:
# array([-57836.73980288, -58016.03583778, -57756.0598844 , ...,
#         60114.5595513 ,  60568.5523709 ,  60288.50524485])

# %%
spmat=np.array([xf1,yf1,zf1])

# %%
scipy.io.savemat('new2.mat', {'shape': spmat})

# %%
data = scipy.io.loadmat('new2.mat')
X = data['shape'][0]
Y = data['shape'][1]
Z = data['shape'][2]

# %%
# %matplotlib notebook

# %%
#new2
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.view_init(90, -90)
#for i in range(4,53215):
surf = ax.plot_trisurf(X, Y, Z, linewidth=0, antialiased=False)
#ax.scatter3D(X, Y, Z, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#new2
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.view_init(90, -90)
#for i in range(4,53215):
surf = ax.plot_trisurf(X, Y, Z, linewidth=0, antialiased=False)
#ax.scatter3D(X, Y, Z, color = "green")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
